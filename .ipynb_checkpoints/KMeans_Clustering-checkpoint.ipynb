# %%
#import all relevant modules
import pandas as pd

from matplotlib import pyplot as plt

from sklearn.cluster import KMeans
from sklearn_extra.cluster import KMedoids
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-65-ad9df4bc5eec> in <module>
#       5
#       6 from sklearn.cluster import KMeans
# ----> 7 from sklearn_extra.cluster import KMedoids
#       8 from sklearn.preprocessing import MinMaxScaler
#       9 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'sklearn_extra'

# %%
#read in the correct dataset
df = pd.read_csv("crash_data_only_numeric_values.csv")
df.head()
# Out:
#    CRASH_YEAR  NUM_LANES  SPD_LIM  CRASH_SEV_CODE  MULTI_VEH_CODE  \
# 0        2000          6       50               0               5
# 1        2000          2      100               0               2
# 2        2000          3      100               0               2
# 3        2000          2      100               0               2
# 4        2000          2       70               0               2
#
#    HOLIDAY_CODE  LG_REGION_DESC_CODE  JUNCTION_TYPE_CODE  \
# 0             0                    1                   3
# 1             0                    8                   4
# 2             0                   12                   4
# 3             0                   12                   4
# 4             3                    2                   3
#
#    DIRN_ROLE1_DESC_CODE  INTSN_MIDBLOCK_CODE  FLAT_HILL_CODE  \
# 0                     3                    0               0
# 1                     2                    1               0
# 2                     2                    1               0
# 3                     3                    1               0
# 4                     5                    0               0
#
#    ROAD_CURVATURE_CODE  ROAD_MARKINGS_CODE  ROAD_SURFACE_CODE  ROAD_WET_CODE  \
# 0                    0                   5                  0              0
# 1                    3                   0                  0              0
# 2                    3                   2                  0              0
# 3                    3                   0                  0              0
# 4                    3                   0                  0              0
#
#    URBAN_CODE  LIGHT_CODE  STREET_LIGHT_CODE  WEATHER_A_CODE    TRAFFIC_CTRL
# 0           1           1                  2               0  Traffic Signal
# 1           0           0                  0               0             Nil
# 2           0           2                  0               0             Nil
# 3           0           0                  0               0             Nil
# 4           1           1                  2               0             Nil

# %%
#creates scale for numeric data (0-1)
#df.drop('TRAFFIC_CTRL', axis='columns', inplace=True)
scaler = MinMaxScaler()
scaler.fit(df)
scaled_df = scaler.transform(df)
#need to change array to df before i can do this
#scaled_df.to_csv('scaled_crash_data.csv', index=False)

# %%
#find all columns to consider
for col in df.columns: 
    print("'" + col + "'" + ", ")
# Out:
# 'CRASH_YEAR',
# 'NUM_LANES',
# 'SPD_LIM',
# 'CRASH_SEV_CODE',
# 'MULTI_VEH_CODE',
# 'HOLIDAY_CODE',
# 'LG_REGION_DESC_CODE',
# 'JUNCTION_TYPE_CODE',
# 'DIRN_ROLE1_DESC_CODE',
# 'INTSN_MIDBLOCK_CODE',
# 'FLAT_HILL_CODE',
# 'ROAD_CURVATURE_CODE',
# 'ROAD_MARKINGS_CODE',
# 'ROAD_SURFACE_CODE',
# 'ROAD_WET_CODE',
# 'URBAN_CODE',
# 'LIGHT_CODE',
# 'STREET_LIGHT_CODE',
# 'WEATHER_A_CODE',
# 'TRAFFIC_CTRL',

# %%
#create KMeans model
km = KMeans(n_clusters=15)
y_predicted = km.fit_predict(df[['CRASH_YEAR', 
'NUM_LANES', 
'SPD_LIM', 
'CRASH_SEV_CODE', 
'MULTI_VEH_CODE', 
'HOLIDAY_CODE', 
'LG_REGION_DESC_CODE', 
'JUNCTION_TYPE_CODE', 
'DIRN_ROLE1_DESC_CODE', 
'INTSN_MIDBLOCK_CODE', 
'FLAT_HILL_CODE', 
'ROAD_CURVATURE_CODE', 
'ROAD_MARKINGS_CODE', 
'ROAD_SURFACE_CODE', 
'ROAD_WET_CODE', 
'URBAN_CODE', 
'LIGHT_CODE', 
'STREET_LIGHT_CODE', 
'WEATHER_A_CODE']])
y_predicted
# Out:
# array([ 5, 11, 11, ..., 10, 10, 10])

# %%
#find cluster centres and add cluster as a column on dataframe
df['CLUSTER']=y_predicted
#df.head()
km.cluster_centers_
# Out:
# array([[ 2.01120326e+03,  3.36965255e+00,  6.00000000e+01,
#          1.81323561e+00,  2.67044894e+00,  2.91676651e+00,
#          3.42603425e+00,  3.39319191e+00,  2.72499824e+00,
#          4.39283952e-01,  8.90126154e-02,  2.51603355e+00,
#          2.61082529e+00,  6.90675876e-03,  7.01881739e-01,
#          1.00000000e+00,  9.99577137e-01,  2.20522940e+00,
#          4.24977095e-01],
#        [ 2.01410199e+03,  2.07757070e+00,  9.99712168e+01,
#          1.78024034e+00,  4.05077835e+00,  2.86001775e+00,
#          1.06701206e+01,  3.75599050e+00,  2.67453407e+00,
#          8.56108033e-01,  3.08387901e-01,  1.75505505e+00,
#          5.35127486e-01,  1.28157156e-01,  1.02281068e+00,
#          1.23678845e-13,  1.11647598e+00,  1.73960807e+00,
#          5.95212396e-01],
#        [ 2.01497764e+03,  2.45976972e+00,  4.99712723e+01,
#          1.81508950e+00,  2.90709838e+00,  2.92393444e+00,
#          2.02552305e+00,  3.32231150e+00,  2.68726823e+00,
#          5.01247539e-01,  1.54603305e-01,  2.51355125e+00,
#          1.19438722e+00,  8.59543103e-03,  6.29812755e-01,
#          1.00000000e+00,  9.58796869e-01,  2.24879824e+00,
#          4.04889438e-01],
#        [ 2.00261171e+03,  2.21190354e+00,  5.02081335e+01,
#          1.83052625e+00,  2.92060588e+00,  2.91025498e+00,
#          1.09386307e+01,  3.41901086e+00,  2.68518973e+00,
#          4.95326477e-01,  1.78686952e-01,  2.46271220e+00,
#          1.19519486e+00,  1.58386687e-02,  7.10152364e-01,
#          1.00000000e+00,  1.05730921e+00,  2.21723515e+00,
#          4.12987708e-01],
#        [ 2.00836710e+03,  2.14260070e+00,  4.99998027e+01,
#          1.82179351e+00,  2.92261412e+00,  2.91734722e+00,
#          1.10540892e+01,  3.39442538e+00,  2.69783406e+00,
#          5.01538644e-01,  1.75385647e-01,  2.43496272e+00,
#          1.14727581e+00,  1.63727463e-02,  6.74537421e-01,
#          1.00000000e+00,  1.04538999e+00,  2.42985363e+00,
#          3.71878329e-01],
#        [ 2.00251524e+03,  2.54275603e+00,  5.00449182e+01,
#          1.85593726e+00,  2.79144984e+00,  2.91772331e+00,
#          1.99890060e+00,  3.26907975e+00,  2.72177956e+00,
#          4.28481682e-01,  1.58501471e-01,  2.43402054e+00,
#          1.19491765e+00,  7.95753191e-03,  7.19769232e-01,
#          1.00000000e+00,  9.95832766e-01,  1.72941250e+00,
#          4.42847121e-01],
#        [ 2.00780688e+03,  8.79994564e-01,  2.64005164e+01,
#          1.86776298e+00,  3.16893177e+00,  2.88570264e+00,
#          5.06102202e+00,  3.61837456e+00,  2.67722207e+00,
#          8.54987768e-01,  1.00842620e-01,  2.60097853e+00,
#          1.12095678e+00,  1.18782278e-01,  4.72954607e-01,
#          1.00000000e+00,  9.13155749e-01,  1.90935037e+00,
#          4.69285132e-01],
#        [ 2.00453047e+03,  2.37111828e+00,  9.99980913e+01,
#          1.79136526e+00,  3.52795221e+00,  2.88027027e+00,
#          2.73929723e+00,  3.85786269e+00,  2.65798866e+00,
#          8.36695742e-01,  2.54862291e-01,  1.97768786e+00,
#          7.00437081e-01,  8.80651995e-02,  9.39247609e-01,
#          1.27897692e-13,  1.07913271e+00,  1.44280725e+00,
#          5.18466207e-01],
#        [ 2.00867758e+03,  2.42331231e+00,  7.00000000e+01,
#          1.80466432e+00,  3.15968101e+00,  2.88510757e+00,
#          5.58753709e+00,  3.36308420e+00,  2.70127040e+00,
#          5.88093472e-01,  1.76696958e-01,  2.09843286e+00,
#          1.41074740e+00,  2.02151335e-02,  8.00676929e-01,
#          1.00000000e+00,  1.03199184e+00,  1.95841061e+00,
#          4.54655045e-01],
#        [ 2.01404847e+03,  2.30090068e+00,  9.99771827e+01,
#          1.77768704e+00,  3.58316320e+00,  2.88973220e+00,
#          2.66379248e+00,  3.83732437e+00,  2.64337697e+00,
#          8.49381530e-01,  2.54257235e-01,  2.06614627e+00,
#          5.79272247e-01,  7.19586886e-02,  9.09403146e-01,
#          1.24789068e-13,  1.05257596e+00,  1.79903927e+00,
#          5.02918218e-01],
#        [ 2.01507117e+03,  2.13548914e+00,  5.00348994e+01,
#          1.82934641e+00,  3.01466658e+00,  2.91752259e+00,
#          1.10335299e+01,  3.39416429e+00,  2.66587149e+00,
#          5.27555055e-01,  1.85563139e-01,  2.44149935e+00,
#          1.08227862e+00,  1.29657853e-02,  6.64369492e-01,
#          1.00000000e+00,  1.00757626e+00,  2.44461379e+00,
#          4.44348729e-01],
#        [ 2.00466324e+03,  2.07717874e+00,  1.00000000e+02,
#          1.76056282e+00,  3.91382570e+00,  2.84872729e+00,
#          1.06610743e+01,  3.74643262e+00,  2.67170179e+00,
#          8.48627779e-01,  3.17989134e-01,  1.68726491e+00,
#          7.64642665e-01,  1.35411069e-01,  1.01747368e+00,
#          1.24122934e-13,  1.12530101e+00,  1.41940812e+00,
#          5.96453520e-01],
#        [ 2.00839338e+03,  2.44236537e+00,  4.99898944e+01,
#          1.82135872e+00,  2.85451167e+00,  2.91903551e+00,
#          2.05241883e+00,  3.26621246e+00,  2.71303299e+00,
#          4.49037250e-01,  1.43391142e-01,  2.44458208e+00,
#          1.12204981e+00,  8.56261138e-03,  6.64873734e-01,
#          1.00000000e+00,  9.80147346e-01,  1.86576911e+00,
#          3.91674273e-01],
#        [ 2.00556821e+03,  2.87184291e+00,  8.00097141e+01,
#          1.80141549e+00,  3.02157924e+00,  2.90500971e+00,
#          4.01831807e+00,  3.73057175e+00,  2.65868721e+00,
#          7.18151540e-01,  2.82542326e-01,  1.97751873e+00,
#          1.38016930e+00,  2.31751318e-02,  8.98626145e-01,
#         -7.21644966e-15,  1.04419928e+00,  1.55717458e+00,
#          4.85359423e-01],
#        [ 2.01446904e+03,  2.55093808e+00,  8.00044823e+01,
#          1.80450791e+00,  3.20253570e+00,  2.90279823e+00,
#          5.41294743e+00,  3.64397772e+00,  2.64967663e+00,
#          7.30421976e-01,  2.85266056e-01,  2.02260357e+00,
#          1.16206698e+00,  4.31580969e-02,  9.40833707e-01,
#          9.99200722e-15,  1.08234616e+00,  2.04450279e+00,
#          5.04258180e-01]])

# %%
#Find the sum of squared error for each number of clusters
sse_scaled = []
sse = []
k_rng = range(1,10)
for k in k_rng:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(df)
    kmeans_scaled = KMeans(n_clusters=k)
    kmeans_scaled.fit(scaled_df)
    sse.append(kmeans.inertia_)
    sse_scaled.append(kmeans_scaled.inertia_)
print("finished")
# Out:
# finished

# %%
#Plot line graph that shows the sum of squared error for each number of k values
# appropriate number of clusters is at the elbow of the plot, the non-scaled clusters looks like 2
plt.xlabel('K')
plt.ylabel('Sum of squared error')
plt.plot(k_rng, sse)

# %%
#Plot line graph that shows the sum of squared error for each number of k values
# appropriate number of clusters is at the elbow of the plot, the scaled clusters looks like 5
plt.xlabel('K')
plt.ylabel('Sum of squared error')
plt.plot(k_rng, sse_scaled)

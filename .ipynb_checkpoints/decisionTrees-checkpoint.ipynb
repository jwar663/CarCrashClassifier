# %%
import multiprocessing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import time
#import lime
#import lime.lime_tabular

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import f1_score

from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold

from matplotlib.legend_handler import HandlerLine2D

#feature importance graphing function
def f_importances(importances, names):
    indices = np.argsort(importances)[::-1]
    print(indices)
    plt.figure()
    plt.subplots(figsize=(20,20))
    plt.title("Feature Importance")
    plt.bar(range(X.shape[1]), importances[indices])
    plt.xticks(range(X.shape[1]), names[indices], rotation=90)
    plt.show()



#df = pd.read_csv("crash_data_one_hot_encoded_MLP.csv")
df = pd.read_csv("final_dataset_with_crash_sev_code.csv")
df = sklearn.utils.shuffle(df)
df.fillna(0,inplace=True)
encode = LabelEncoder()


df_non_injury = df[df.CRASH_SEV_CODE==2]  # 480452 samples
df_minor = df[df.CRASH_SEV_CODE==1]       # 150834 samples
df_serious = df[df.CRASH_SEV_CODE==3]    # 37347  samples
df_fatal = df[df.CRASH_SEV_CODE==0]       # 6178   samples

#upsampling all classes to match largest class (non_injury)
df_minor_upsampled = resample(df_minor, replace=True,n_samples=480452,random_state=40)
df_serious_upsampled = resample(df_serious, replace=True,n_samples=480452,random_state=40)
df_fatal_upsampled = resample(df_fatal, replace=True,n_samples=480452,random_state=40)

#downsampling all classes to match smallest class (fatal)
df_minor_downsampled= resample(df_minor, replace=False,n_samples=6178,random_state=40)
df_serious_downsampled = resample(df_serious, replace=False,n_samples=6178,random_state=40)
df_non_injury_downsampled = resample(df_non_injury, replace=False,n_samples=6178,random_state=40)


df_upsampled = pd.concat([df_non_injury, df_minor_upsampled, df_serious_upsampled, df_fatal_upsampled])
df_upsampled.CRASH_SEV_CODE.value_counts()

#df_downsampled = pd.concat([df_fatal, df_minor_downsampled, df_serious_downsampled, df_non_injury_downsampled])
#df_downsampled.CRASH_SEV_CODE.value_counts()
# Out:
# 3    480452
# 2    480452
# 1    480452
# 0    480452
# Name: CRASH_SEV_CODE, dtype: int64

# %%
X = df_upsampled.drop(["CRASH_SEV_CODE","CRASH_YEAR"], axis=1).values
features = df_upsampled.drop(["CRASH_SEV_CODE","CRASH_YEAR"], axis=1)
y = df_upsampled["CRASH_SEV_CODE"].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=40)
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

clf = DecisionTreeClassifier(random_state = 30)

print(X_train.shape); print(X_test.shape)
# Out:
# (1729627, 80)
# (192181, 80)

# %%
start = time.time()
clf.fit(X_train,y_train)
stop = time.time()

predict_train = clf.predict(X_train)
predict_test = clf.predict(X_test)
print(f"\n Training time: {stop - start}s")
print("\n training data\n")
print(confusion_matrix(y_train,predict_train))
print("\n")
print(classification_report(y_train,predict_train,labels=pd.unique(predict_train)))
print("\n---------------------------------------------------------------------------------------\n")
print("\n test data\n")
print(confusion_matrix(y_test,predict_test))
print("\n")
print(classification_report(y_test,predict_test,labels=pd.unique(predict_test)))
# Out:
#  Training time: 41.90611410140991s
#
#  training data
#
# [[425121   1098   1633   4548]
#  [ 22745 314979  49338  45405]
#  [ 15569  56525 328376  32162]
#  [ 31296  17917  16336 366579]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92    432400
#            1       0.81      0.73      0.77    432467
#            2       0.83      0.76      0.79    432632
#            3       0.82      0.85      0.83    432128
#
#     accuracy                           0.83   1729627
#    macro avg       0.83      0.83      0.83   1729627
# weighted avg       0.83      0.83      0.83   1729627
#
#
# ---------------------------------------------------------------------------------------
#
#
#  test data
#
# [[47210   131   183   528]
#  [ 2454 33109  6964  5458]
#  [ 2087 11004 29668  5061]
#  [ 3525  2162  1913 40724]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91     48052
# ...

# %%
scores = []
kf = KFold() #defualt 5 folds
for train_index, test_index in kf.split(X):
    print("Train Index: ", train_index, "\n")
    print("Test Index: ", test_index)

    X_train, X_test, y_train, y_test = X[train_index], X[test_index], y[train_index], y[test_index]
    clf.fit(X_train, y_train)
    scores.append(clf.score(X_test, y_test))
# Out:
# Train Index:  [ 4943  4944  4945 ... 24709 24710 24711]
#
# Test Index:  [   0    1    2 ... 4940 4941 4942]
# Train Index:  [    0     1     2 ... 24709 24710 24711]
#
# Test Index:  [4943 4944 4945 ... 9883 9884 9885]
# Train Index:  [    0     1     2 ... 24709 24710 24711]
#
# Test Index:  [ 9886  9887  9888 ... 14825 14826 14827]
# Train Index:  [    0     1     2 ... 24709 24710 24711]
#
# Test Index:  [14828 14829 14830 ... 19767 19768 19769]
# Train Index:  [    0     1     2 ... 19767 19768 19769]
#
# Test Index:  [19770 19771 19772 ... 24709 24710 24711]

# %%
max_depths = np.linspace(1, 200, 200, endpoint=True)
train_results = []
test_results = []
training_time = []
for max_depth in max_depths:
   dt = DecisionTreeClassifier(max_depth=max_depth)

   start = time.time()
   dt.fit(X_train, y_train)
   stop = time.time()

   training_time.append(stop - start) 

   predict_train = dt.predict(X_train)
   score = f1_score(y_train,predict_train,labels=pd.unique(predict_train),average='weighted')
   train_results.append(score)

   predict_test = dt.predict(X_test)
   score1 = f1_score(y_test,predict_test,labels=pd.unique(predict_test),average='weighted')
   test_results.append(score1)
    

line1, = plt.plot(max_depths, train_results, 'b', label="Train AUC")
line2, = plt.plot(max_depths, test_results, 'r', label="Test AUC")
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel('f1_score')
plt.xlabel('Tree depth')
plt.show()

time_line, = plt.plot(max_depths, training_time, 'r', label="time taken")
plt.legend(handler_map={time_line: HandlerLine2D(numpoints=1)})
plt.ylabel('time (mins)')
plt.xlabel('num trees')
plt.show()

# %%
time_line, = plt.plot(max_depths, training_time, 'r', label="time taken")
plt.legend(handler_map={time_line: HandlerLine2D(numpoints=1)})
plt.ylabel('time (secs)')
plt.xlabel('max depths')
plt.show()

# %%
min_splits = range(2,20)
train_results1 = []
test_results1 = []
training_time1 = []
for splits in min_splits:
   dt = DecisionTreeClassifier(min_samples_split = splits)

   start = time.time()
   dt.fit(X_train, y_train)
   stop = time.time()
    
   training_time1.append(stop - start)
    
   predict_train = dt.predict(X_train)
   score = f1_score(y_train,predict_train,labels=pd.unique(predict_train),average='weighted')
   train_results1.append(score)

   predict_test = dt.predict(X_test)
   score1 = f1_score(y_test,predict_test,labels=pd.unique(predict_test),average='weighted')
   test_results1.append(score1)
    
line1, = plt.plot(min_splits, train_results1, 'b', label="Train score")
line2, = plt.plot(min_splits, test_results1, 'r', label="Test score")
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel('f1_score')
plt.xlabel('min samples split')
plt.show()

time_line, = plt.plot(min_splits, training_time1, 'r', label="time taken")
plt.legend(handler_map={time_line: HandlerLine2D(numpoints=1)})
plt.ylabel('time (secs)')
plt.xlabel('min samples splits')
plt.show()

# %%
min_samples_leafs  = range(1,10)
train_results2 = []
test_results2 = []
training_time2 = []
for min_samples in min_samples_leafs:
   dt = DecisionTreeClassifier(min_samples_leaf = min_samples)

   start = time.time()
   dt.fit(X_train, y_train)
   stop = time.time()
    
   training_time2.append(stop - start)
    
    
   predict_train = dt.predict(X_train)
   score = f1_score(y_train,predict_train,labels=pd.unique(predict_train),average='weighted')
   train_results2.append(score)

   predict_test = dt.predict(X_test)
   score1 = f1_score(y_test,predict_test,labels=pd.unique(predict_test),average='weighted')
   test_results2.append(score1)
    
line1, = plt.plot(min_samples_leafs, train_results2, 'b', label="Train score")
line2, = plt.plot(min_samples_leafs, test_results2, 'r', label="Test score")
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel('f1_score')
plt.xlabel('min samples leaf')
plt.show()

time_line, = plt.plot(min_samples_leafs, training_time2, 'r', label="time taken")
plt.legend(handler_map={time_line: HandlerLine2D(numpoints=1)})
plt.ylabel('time (secs)')
plt.xlabel('min samples leafs')
plt.show()

# %%
max_features = list(range(1,X.shape[1]))
train_results3 = []
test_results3 = []
for max_feature in max_features:
   dt = DecisionTreeClassifier(min_samples_leaf = min_samples)
   
   start = time.time()
   dt.fit(X_train, y_train)
   stop = time.time()
    
   training_time2.append(stop - start)
    
   predict_train = dt.predict(X_train)
   score = f1_score(y_train,predict_train,labels=pd.unique(predict_train),average='weighted')
   train_results3.append(score)

   predict_test = dt.predict(X_test)
   score1 = f1_score(y_test,predict_test,labels=pd.unique(predict_test),average='weighted')
   test_results3.append(score1)
    
line1, = plt.plot(max_features, train_results3, 'b', label="Train score")
line2, = plt.plot(max_features, test_results3, 'r', label="Test score")
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel('f1_score')
plt.xlabel('min samples leaf')
plt.show()

# %%
df_noYear = df_upsampled.drop(["CRASH_YEAR"], axis=1)
f_importances(clf.feature_importances_, df_noYear.columns.values)
print(train_results)
print(test_results)
# Out:
# [ 1  0 10 46 47 49 45 60 76 78 52 23 53 58 13 55  3 56 85 87 61 70 77 20
#  81 41 62 73 34 25 35 28 82 65 30 40  2 84 27 24 86 79 63 17 57 29  6 33
#  42 31 51 83  7 50 32 18 88 67 37 26 19 36 14 21 39 15 69 43 75 90 64 74
#  71 38  9 66 16 54 89 72 80 11  5  8  4 12 22 48 44 59 68]
# []
# [0.4838463669631407, 0.4562501062037626, 0.3759650044216775, 0.4046524623360831, 0.4238079348048285, 0.4259641466342381, 0.430135070035511, 0.4399322483519162, 0.445484832187188, 0.454600780523314, 0.465377016620459, 0.47093907328615303, 0.48636561813947116, 0.5026079123865846, 0.523211287123202, 0.5420662585748187, 0.563280997329909, 0.5822113237756729, 0.6018195293885126, 0.6204704798584847, 0.6386333446517964, 0.6563795176117617, 0.6718716177067351, 0.6865047958905129, 0.6994294523226671, 0.71149470780789, 0.7224199470890901, 0.7329983638214457, 0.7404110964057871, 0.7465106376049383, 0.7535137138652103, 0.758351168058311]

# %%
# From this cell and below, random forests are used
from sklearn.ensemble import RandomForestClassifier

clf2 = RandomForestClassifier(random_state=40,verbose = True)

# %%
start = time.time()
clf2.fit(X_train,y_train)
stop = time.time()

predict_train = clf2.predict(X_train)
predict_test = clf2.predict(X_test)
print(f"\n Training time: {stop - start}s")
print("\n training data\n")
print(confusion_matrix(y_train,predict_train))
print("\n")
print(classification_report(y_train,predict_train,labels=pd.unique(predict_train)))
print("\n---------------------------------------------------------------------------------------\n")
print("\n test data\n")
print(confusion_matrix(y_test,predict_test))
print("\n")
print(classification_report(y_test,predict_test,labels=pd.unique(predict_test)))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:  7.9min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:   59.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    6.7s finished
#  Training time: 476.9131209850311s
#
#  training data
#
# [[425279   1312   1307   4502]
#  [ 22635 310332  52881  46619]
#  [ 15731  52097 331612  33192]
#  [ 31134  17019  15395 368580]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92    432400
#            1       0.82      0.72      0.76    432467
#            3       0.81      0.85      0.83    432128
#            2       0.83      0.77      0.80    432632
#
#     accuracy                           0.83   1729627
# ...

# %%
#export classification model
from joblib import dump, load
dump(clf2, 'random_forest_classification_model.joblib')

# %%
df_noYear = df_upsampled.drop(["CRASH_YEAR"], axis=1)
f_importances(clf2.feature_importances_, df_noYear.columns.values)
# Out:
# [ 0  1 46 47 10 49 45  3 60 58 23 52 53 78 56 55 15 76 34 75 74 25 61 81
#  13 20 85 87 24 28 35 70 65 62 73 30 77 31 27 40  2 63 41 84 82 29 14 17
#  79 86 33 57 32  6 42 83 37 50  7 51 88 18 36 26 21 19 69 67 39 64 43 90
#  71 38  9 16 66 54 89 72 80 11  8  5  4 12 22 48 44 68 59]

# %%
n_estimators = [1, 2, 4, 8, 16, 32, 64, 100, 200]
train_results4 = []
test_results4 = []
training_time4 = [] # in mins
for estimator in n_estimators:
   rf = RandomForestClassifier(n_estimators=estimator,n_jobs=-1, verbose = True)

   start = time.time()
   rf.fit(X_train, y_train)
   stop = time.time()
    
   training_time4.append((stop - start)/60)
    
    
   predict_train = rf.predict(X_train)
   score = f1_score(y_train,predict_train,labels=pd.unique(predict_train),average='weighted')
   train_results4.append(score)

   predict_test = rf.predict(X_test)
   score1 = f1_score(y_test,predict_test,labels=pd.unique(predict_test),average='weighted')
   test_results4.append(score1)
    
from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(n_estimators, train_results4, 'b', label="Train score")
line2, = plt.plot(n_estimators, test_results4, 'r', label="Test score")
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel('f1_score')
plt.xlabel('min samples leaf')
plt.show()

time_line, = plt.plot(n_estimators, training_time4, 'r', label="time taken")
plt.legend(handler_map={time_line: HandlerLine2D(numpoints=1)})
plt.ylabel('time (mins)')
plt.xlabel('num trees')
plt.show()
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    5.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    5.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    5.6s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done   2 out of   2 | elapsed:    0.7s finished
# ...

# %%
n_cores = range(1,multiprocessing.cpu_count())

training_time5 = [] # in mins
for cores in n_cores:
   rf = RandomForestClassifier(n_jobs=cores, verbose = True)

   start = time.time()
   rf.fit(X_train, y_train)
   stop = time.time()
    
   training_time5.append((stop - start)/60)
    
    
  
    

time_line, = plt.plot(n_cores, training_time5, 'r', label="time taken")
plt.legend(handler_map={time_line: HandlerLine2D(numpoints=1)})
plt.ylabel('time (mins)')
plt.xlabel('num cores')
plt.show()
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:  8.7min finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=2)]: Done 100 out of 100 | elapsed:  5.0min finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:  3.7min finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:  3.0min finished
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:  1.0min
# ...

# %%
explainer = lime.lime_tabular.LimeTabularExplainer(X_train,
                    feature_names=features.columns.tolist(), 
                    training_labels=y_train,                              
                    feature_selection="lasso_path",
                    class_names=["fatal", "minor","non-injury","serious"],
                    discretize_continuous=True,
                    discretizer="entropy", 
                
                    # There is no categorical features in this example, otherwise specify them.                               
                    verbose=True)

# %%
exp = explainer.explain_instance(X_test[10], clf.predict_proba, num_features=9,top_labels=4)
 
exp.show_in_notebook(show_table=True)
# Out:
# Intercept 0.09152347199828831
# Prediction_local [0.01448291]
# Right: 0.0
# Intercept 0.35051130617194415
# Prediction_local [0.53804633]
# Right: 0.22857142857142856
# Intercept 0.22950368147532763
# Prediction_local [0.30457861]
# Right: 0.2571428571428571
# Intercept 0.20878205780545617
# Prediction_local [0.12549766]
# Right: 0.5142857142857142
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# ...

# %%
#import and identify columns
import pandas as pd

crash_data = pd.read_csv("crash_data_one_hot_encoded.csv")

for col in crash_data.columns: 
    print("'" + col + "'" + ", ")
# Out:
# 'CRASH_YEAR',
# 'NUM_LANES',
# 'SPD_LIM',
# 'TRAFFIC_CTRL_Give Way Sign',
# 'TRAFFIC_CTRL_Nil',
# 'TRAFFIC_CTRL_Points Man',
# 'TRAFFIC_CTRL_School Patrol',
# 'TRAFFIC_CTRL_Stop Sign',
# 'TRAFFIC_CTRL_Traffic Signal',
# 'CRASH_SEV_F',
# 'CRASH_SEV_M',
# 'CRASH_SEV_N',
# 'CRASH_SEV_S',
# 'MULTI_VEH_Cyclist(s)+Pedestrian(s) only',
# 'MULTI_VEH_Cyclists only',
# 'MULTI_VEH_Multi vehicle',
# 'MULTI_VEH_Other',
# 'MULTI_VEH_Others without non-parked veh',
# 'MULTI_VEH_Single vehicle',
# 'MULTI_VEH_Vehicle(s)+Cyclist(s) only',
# 'MULTI_VEH_Vehicle(s)+Pedestrian(s)',
# 'MULTI_VEH_Vehicle(s)+multiple other types',
# 'HOLIDAY_Christmas/New Year',
# 'HOLIDAY_Easter',
# 'HOLIDAY_Labour Weekend',
# 'HOLIDAY_None',
# 'HOLIDAY_Queens Birthday',
# 'LG_REGION_DESC_0',
# 'LG_REGION_DESC_Auckland            ',
# 'LG_REGION_DESC_Bay of Plenty       ',
# 'LG_REGION_DESC_Canterbury          ',
# 'LG_REGION_DESC_Gisborne            ',
# 'LG_REGION_DESC_Hawkes Bay          ',
# ...

# %%
#simply remove unknown values
def processData(data, keep_col_array):
    processed_data = data[keep_col_array]
    return processed_data

keep_col_array = ['CRASH_YEAR', 
'NUM_LANES', 
'SPD_LIM', 
'TRAFFIC_CTRL_Give Way Sign', 
'TRAFFIC_CTRL_Nil', 
'TRAFFIC_CTRL_Points Man', 
'TRAFFIC_CTRL_School Patrol', 
'TRAFFIC_CTRL_Stop Sign', 
'TRAFFIC_CTRL_Traffic Signal', 
'CRASH_SEV_F', 
'CRASH_SEV_M', 
'CRASH_SEV_N', 
'CRASH_SEV_S', 
'MULTI_VEH_Cyclist(s)+Pedestrian(s) only', 
'MULTI_VEH_Cyclists only', 
'MULTI_VEH_Multi vehicle', 
'MULTI_VEH_Other', 
'MULTI_VEH_Others without non-parked veh', 
'MULTI_VEH_Single vehicle', 
'MULTI_VEH_Vehicle(s)+Cyclist(s) only', 
'MULTI_VEH_Vehicle(s)+Pedestrian(s)', 
'MULTI_VEH_Vehicle(s)+multiple other types', 
'HOLIDAY_Christmas/New Year', 
'HOLIDAY_Easter', 
'HOLIDAY_Labour Weekend', 
'HOLIDAY_None', 
'HOLIDAY_Queens Birthday', 
'LG_REGION_DESC_0', 
'LG_REGION_DESC_Auckland            ', 
'LG_REGION_DESC_Bay of Plenty       ', 
'LG_REGION_DESC_Canterbury          ', 
'LG_REGION_DESC_Gisborne            ', 
'LG_REGION_DESC_Hawkes Bay          ', 
'LG_REGION_DESC_Manawatu/Wanganui   ', 
'LG_REGION_DESC_Nelson/Marlborough  ', 
'LG_REGION_DESC_Northland           ', 
'LG_REGION_DESC_Otago               ', 
'LG_REGION_DESC_Southland           ', 
'LG_REGION_DESC_Taranaki            ', 
'LG_REGION_DESC_Waikato             ', 
'LG_REGION_DESC_Wellington          ', 
'LG_REGION_DESC_West Coast          ', 
'JUNCTION_TYPE_Driveway', 
'JUNCTION_TYPE_Multi Rd Join', 
'JUNCTION_TYPE_Roundabout', 
'JUNCTION_TYPE_T Type Junction',  
'JUNCTION_TYPE_X Type Junction', 
'JUNCTION_TYPE_Y Type Junction', 
'DIRN_ROLE1_DESC_0', 
'DIRN_ROLE1_DESC_East', 
'DIRN_ROLE1_DESC_North', 
'DIRN_ROLE1_DESC_South',  
'DIRN_ROLE1_DESC_West', 
'INTSN_MIDBLOCK_Intersection', 
'INTSN_MIDBLOCK_Mid Block', 
'FLAT_HILL_Flat', 
'FLAT_HILL_Hill',  
'ROAD_CURVATURE_Easy Curve', 
'ROAD_CURVATURE_Moderate Curve', 
'ROAD_CURVATURE_Severe Curve', 
'ROAD_CURVATURE_Straight Road',  
'ROAD_MARKINGS_Centre Line', 
'ROAD_MARKINGS_No Marks', 
'ROAD_MARKINGS_No Passing Lines', 
'ROAD_MARKINGS_Painted Island', 
'ROAD_MARKINGS_Ped Crossing', 
'ROAD_MARKINGS_Raised Island', 
'ROAD_SURFACE_Sealed', 
'ROAD_SURFACE_Unsealed', 
'ROAD_WET_Dry', 
'ROAD_WET_Ice/ Snow', 
'ROAD_WET_Wet', 
'URBAN_Openroad', 
'URBAN_Urban', 
'LIGHT_Bright Sun', 
'LIGHT_Dark', 
'LIGHT_Overcast', 
'LIGHT_Twilight',  
'STREET_LIGHT_None', 
'STREET_LIGHT_Off', 
'STREET_LIGHT_On',  
'WEATHER_A_Fine', 
'WEATHER_A_Heavy Rain', 
'WEATHER_A_Light Rain', 
'WEATHER_A_Mist', 
'WEATHER_A_Snow']
#processed_crash_data = processData(crash_data, keep_col_array)
#processed_crash_data.to_csv('crash_data_one_hot_encoded_without_unknowns.csv', index=False)

# %%
#taking the mean
#find mean of each value that has an unknown
mean_df = crash_data.mean(axis=0)
mean_df
# Out:
# CRASH_YEAR                    2008.741882
# NUM_LANES                        2.349959
# SPD_LIM                         65.720676
# TRAFFIC_CTRL_Give Way Sign       0.177713
# TRAFFIC_CTRL_Nil                 0.423545
#                                  ...
# WEATHER_A_Heavy Rain             0.042102
# WEATHER_A_Light Rain             0.153659
# WEATHER_A_Mist                   0.013558
# WEATHER_A_Snow                   0.002141
# WEATHER_A_Unknown                0.011625
# Length: 96, dtype: float64

# %%
#taking the median
median_df = crash_data.median(axis=0)
median_df
# Out:
# CRASH_YEAR                    2008.0
# NUM_LANES                        2.0
# SPD_LIM                         50.0
# TRAFFIC_CTRL_Give Way Sign       0.0
# TRAFFIC_CTRL_Nil                 0.0
#                                ...
# WEATHER_A_Heavy Rain             0.0
# WEATHER_A_Light Rain             0.0
# WEATHER_A_Mist                   0.0
# WEATHER_A_Snow                   0.0
# WEATHER_A_Unknown                0.0
# Length: 96, dtype: float64

# %%
#taking the mode
mode_df = crash_data.mode(axis=0)
mode_df
# Out:
#    CRASH_YEAR  NUM_LANES  SPD_LIM  TRAFFIC_CTRL_Give Way Sign  \
# 0        2007          2       50                           0
#
#    TRAFFIC_CTRL_Nil  TRAFFIC_CTRL_Points Man  TRAFFIC_CTRL_School Patrol  \
# 0                 0                        0                           0
#
#    TRAFFIC_CTRL_Stop Sign  TRAFFIC_CTRL_Traffic Signal  CRASH_SEV_F  ...  \
# 0                       0                            0            0  ...
#
#    STREET_LIGHT_None  STREET_LIGHT_Off  STREET_LIGHT_On  STREET_LIGHT_Unknown  \
# 0                  0                 0                0                     0
#
#    WEATHER_A_Fine  WEATHER_A_Heavy Rain  WEATHER_A_Light Rain  WEATHER_A_Mist  \
# 0               1                     0                     0               0
#
#    WEATHER_A_Snow  WEATHER_A_Unknown
# 0               0                  0
#
# [1 rows x 96 columns]

# %%
#convert values for mean
mean_crash_data = crash_data

mean_crash_data['STREET_LIGHT_None'] = [[mean_df['STREET_LIGHT_None']] if x == 1 else x for x in crash_data['STREET_LIGHT_Unknown']]
#mean_df['WEATHER_A_Fine']
mean_crash_data['STREET_LIGHT_Off'] = [[mean_df['STREET_LIGHT_Off']] if x == 1 else x for x in crash_data['STREET_LIGHT_Unknown']]
mean_crash_data['STREET_LIGHT_On'] = [[mean_df['STREET_LIGHT_On']] if x == 1 else x for x in crash_data['STREET_LIGHT_Unknown']]
#print(mean_crash_data.loc[[22060]])

mean_crash_data['WEATHER_A_Fine'] = [[mean_df['WEATHER_A_Fine']] if x == 1 else x for x in crash_data['WEATHER_A_Unknown']]
mean_crash_data['WEATHER_A_Heavy Rain'] = [[mean_df['WEATHER_A_Heavy Rain']] if x == 1 else x for x in crash_data['WEATHER_A_Unknown']]
mean_crash_data['WEATHER_A_Light Rain'] = [[mean_df['WEATHER_A_Light Rain']] if x == 1 else x for x in crash_data['WEATHER_A_Unknown']]
mean_crash_data['WEATHER_A_Mist'] = [[mean_df['WEATHER_A_Mist']] if x == 1 else x for x in crash_data['WEATHER_A_Unknown']]
mean_crash_data['WEATHER_A_Snow'] = [[mean_df['WEATHER_A_Snow']] if x == 1 else x for x in crash_data['WEATHER_A_Unknown']]

mean_crash_data['LIGHT_Twilight'] = [[mean_df['LIGHT_Twilight']] if x == 1 else x for x in crash_data['LIGHT_Unknown']]
mean_crash_data['LIGHT_Overcast'] = [[mean_df['LIGHT_Overcast']] if x == 1 else x for x in crash_data['LIGHT_Unknown']]
mean_crash_data['LIGHT_Dark'] = [[mean_df['LIGHT_Dark']] if x == 1 else x for x in crash_data['LIGHT_Unknown']]
mean_crash_data['LIGHT_Bright Sun'] = [[mean_df['LIGHT_Bright Sun']] if x == 1 else x for x in crash_data['LIGHT_Unknown']]

mean_crash_data['ROAD_WET_Wet'] = [[mean_df['ROAD_WET_Wet']] if x == 1 else x for x in crash_data['ROAD_WET_Unknown']]
mean_crash_data['ROAD_WET_Ice/ Snow'] = [[mean_df['ROAD_WET_Ice/ Snow']] if x == 1 else x for x in crash_data['ROAD_WET_Unknown']]
mean_crash_data['ROAD_WET_Dry'] = [[mean_df['ROAD_WET_Dry']] if x == 1 else x for x in crash_data['ROAD_WET_Unknown']]

mean_crash_data['ROAD_SURFACE_Unsealed'] = [[mean_df['ROAD_SURFACE_Unsealed']] if x == 1 else x for x in crash_data['ROAD_SURFACE_Unknown']]
mean_crash_data['ROAD_SURFACE_Sealed'] = [[mean_df['ROAD_SURFACE_Sealed']] if x == 1 else x for x in crash_data['ROAD_SURFACE_Unknown']]


mean_crash_data['ROAD_MARKINGS_Raised Island'] = [[mean_df['ROAD_MARKINGS_Raised Island']] if x == 1 else x for x in crash_data['ROAD_MARKINGS_Unknown']]
mean_crash_data['ROAD_MARKINGS_Ped Crossing'] = [[mean_df['ROAD_MARKINGS_Ped Crossing']] if x == 1 else x for x in crash_data['ROAD_MARKINGS_Unknown']]
mean_crash_data['ROAD_MARKINGS_Painted Island'] = [[mean_df['ROAD_MARKINGS_Painted Island']] if x == 1 else x for x in crash_data['ROAD_MARKINGS_Unknown']]
mean_crash_data['ROAD_MARKINGS_No Passing Lines'] = [[mean_df['ROAD_MARKINGS_No Passing Lines']] if x == 1 else x for x in crash_data['ROAD_MARKINGS_Unknown']]
mean_crash_data['ROAD_MARKINGS_No Marks'] = [[mean_df['ROAD_MARKINGS_No Marks']] if x == 1 else x for x in crash_data['ROAD_MARKINGS_Unknown']]
mean_crash_data['ROAD_MARKINGS_Centre Line'] = [[mean_df['ROAD_MARKINGS_Centre Line']] if x == 1 else x for x in crash_data['ROAD_MARKINGS_Unknown']]

mean_crash_data['ROAD_CURVATURE_Straight Road'] = [[mean_df['ROAD_CURVATURE_Straight Road']] if x == 1 else x for x in crash_data['ROAD_CURVATURE_Unknown']]
mean_crash_data['ROAD_CURVATURE_Severe Curve'] = [[mean_df['ROAD_CURVATURE_Severe Curve']] if x == 1 else x for x in crash_data['ROAD_CURVATURE_Unknown']]
mean_crash_data['ROAD_CURVATURE_Moderate Curve'] = [[mean_df['ROAD_CURVATURE_Moderate Curve']] if x == 1 else x for x in crash_data['ROAD_CURVATURE_Unknown']]
mean_crash_data['ROAD_CURVATURE_Easy Curve'] = [[mean_df['ROAD_CURVATURE_Easy Curve']] if x == 1 else x for x in crash_data['ROAD_CURVATURE_Unknown']]

mean_crash_data['FLAT_HILL_Hill'] = [[mean_df['FLAT_HILL_Hill']] if x == 1 else x for x in crash_data['FLAT_HILL_Unknown']]
mean_crash_data['FLAT_HILL_Flat'] = [[mean_df['FLAT_HILL_Flat']] if x == 1 else x for x in crash_data['FLAT_HILL_Unknown']]

mean_crash_data['DIRN_ROLE1_DESC_West'] = [[mean_df['DIRN_ROLE1_DESC_West']] if x == 1 else x for x in crash_data['DIRN_ROLE1_DESC_Unknown']]
mean_crash_data['DIRN_ROLE1_DESC_South'] = [[mean_df['DIRN_ROLE1_DESC_South']] if x == 1 else x for x in crash_data['DIRN_ROLE1_DESC_Unknown']]
mean_crash_data['DIRN_ROLE1_DESC_0'] = [[mean_df['DIRN_ROLE1_DESC_0']] if x == 1 else x for x in crash_data['DIRN_ROLE1_DESC_Unknown']]
mean_crash_data['DIRN_ROLE1_DESC_East'] = [[mean_df['DIRN_ROLE1_DESC_East']] if x == 1 else x for x in crash_data['DIRN_ROLE1_DESC_Unknown']]
mean_crash_data['DIRN_ROLE1_DESC_North'] = [[mean_df['DIRN_ROLE1_DESC_North']] if x == 1 else x for x in crash_data['DIRN_ROLE1_DESC_Unknown']]

mean_crash_data['JUNCTION_TYPE_Y Type Junction'] = [[mean_df['JUNCTION_TYPE_Y Type Junction']] if x == 1 else x for x in crash_data['JUNCTION_TYPE_Unknown']]
mean_crash_data['JUNCTION_TYPE_X Type Junction'] = [[mean_df['JUNCTION_TYPE_X Type Junction']] if x == 1 else x for x in crash_data['JUNCTION_TYPE_Unknown']]
mean_crash_data['JUNCTION_TYPE_T Type Junction'] = [[mean_df['JUNCTION_TYPE_T Type Junction']] if x == 1 else x for x in crash_data['JUNCTION_TYPE_Unknown']]
mean_crash_data['JUNCTION_TYPE_Roundabout'] = [[mean_df['JUNCTION_TYPE_Roundabout']] if x == 1 else x for x in crash_data['JUNCTION_TYPE_Unknown']]
mean_crash_data['JUNCTION_TYPE_Multi Rd Join'] = [[mean_df['JUNCTION_TYPE_Multi Rd Join']] if x == 1 else x for x in crash_data['JUNCTION_TYPE_Unknown']]
mean_crash_data['JUNCTION_TYPE_Driveway'] = [[mean_df['JUNCTION_TYPE_Driveway']] if x == 1 else x for x in crash_data['JUNCTION_TYPE_Unknown']]

mean_crash_data = processData(mean_crash_data, keep_col_array)
mean_crash_data.to_csv('crash_data_mean_unknowns.csv', index=False)

# %%
#convert values for median
median_crash_data = crash_data

median_crash_data['STREET_LIGHT_None'] = [[median_df['STREET_LIGHT_None']] if x == 1 else x for x in crash_data['STREET_LIGHT_Unknown']]
#median_df['WEATHER_A_Fine']
median_crash_data['STREET_LIGHT_Off'] = [[median_df['STREET_LIGHT_Off']] if x == 1 else x for x in crash_data['STREET_LIGHT_Unknown']]
median_crash_data['STREET_LIGHT_On'] = [[median_df['STREET_LIGHT_On']] if x == 1 else x for x in crash_data['STREET_LIGHT_Unknown']]
#print(median_crash_data.loc[[22060]])

median_crash_data['WEATHER_A_Fine'] = [[median_df['WEATHER_A_Fine']] if x == 1 else x for x in crash_data['WEATHER_A_Unknown']]
median_crash_data['WEATHER_A_Heavy Rain'] = [[median_df['WEATHER_A_Heavy Rain']] if x == 1 else x for x in crash_data['WEATHER_A_Unknown']]
median_crash_data['WEATHER_A_Light Rain'] = [[median_df['WEATHER_A_Light Rain']] if x == 1 else x for x in crash_data['WEATHER_A_Unknown']]
median_crash_data['WEATHER_A_Mist'] = [[median_df['WEATHER_A_Mist']] if x == 1 else x for x in crash_data['WEATHER_A_Unknown']]
median_crash_data['WEATHER_A_Snow'] = [[median_df['WEATHER_A_Snow']] if x == 1 else x for x in crash_data['WEATHER_A_Unknown']]

median_crash_data['LIGHT_Twilight'] = [[median_df['LIGHT_Twilight']] if x == 1 else x for x in crash_data['LIGHT_Unknown']]
median_crash_data['LIGHT_Overcast'] = [[median_df['LIGHT_Overcast']] if x == 1 else x for x in crash_data['LIGHT_Unknown']]
median_crash_data['LIGHT_Dark'] = [[median_df['LIGHT_Dark']] if x == 1 else x for x in crash_data['LIGHT_Unknown']]
median_crash_data['LIGHT_Bright Sun'] = [[median_df['LIGHT_Bright Sun']] if x == 1 else x for x in crash_data['LIGHT_Unknown']]

median_crash_data['ROAD_WET_Wet'] = [[median_df['ROAD_WET_Wet']] if x == 1 else x for x in crash_data['ROAD_WET_Unknown']]
median_crash_data['ROAD_WET_Ice/ Snow'] = [[median_df['ROAD_WET_Ice/ Snow']] if x == 1 else x for x in crash_data['ROAD_WET_Unknown']]
median_crash_data['ROAD_WET_Dry'] = [[median_df['ROAD_WET_Dry']] if x == 1 else x for x in crash_data['ROAD_WET_Unknown']]

median_crash_data['ROAD_SURFACE_Unsealed'] = [[median_df['ROAD_SURFACE_Unsealed']] if x == 1 else x for x in crash_data['ROAD_SURFACE_Unknown']]
median_crash_data['ROAD_SURFACE_Sealed'] = [[median_df['ROAD_SURFACE_Sealed']] if x == 1 else x for x in crash_data['ROAD_SURFACE_Unknown']]


median_crash_data['ROAD_MARKINGS_Raised Island'] = [[median_df['ROAD_MARKINGS_Raised Island']] if x == 1 else x for x in crash_data['ROAD_MARKINGS_Unknown']]
median_crash_data['ROAD_MARKINGS_Ped Crossing'] = [[median_df['ROAD_MARKINGS_Ped Crossing']] if x == 1 else x for x in crash_data['ROAD_MARKINGS_Unknown']]
median_crash_data['ROAD_MARKINGS_Painted Island'] = [[median_df['ROAD_MARKINGS_Painted Island']] if x == 1 else x for x in crash_data['ROAD_MARKINGS_Unknown']]
median_crash_data['ROAD_MARKINGS_No Passing Lines'] = [[median_df['ROAD_MARKINGS_No Passing Lines']] if x == 1 else x for x in crash_data['ROAD_MARKINGS_Unknown']]
median_crash_data['ROAD_MARKINGS_No Marks'] = [[median_df['ROAD_MARKINGS_No Marks']] if x == 1 else x for x in crash_data['ROAD_MARKINGS_Unknown']]
median_crash_data['ROAD_MARKINGS_Centre Line'] = [[median_df['ROAD_MARKINGS_Centre Line']] if x == 1 else x for x in crash_data['ROAD_MARKINGS_Unknown']]

median_crash_data['ROAD_CURVATURE_Straight Road'] = [[median_df['ROAD_CURVATURE_Straight Road']] if x == 1 else x for x in crash_data['ROAD_CURVATURE_Unknown']]
median_crash_data['ROAD_CURVATURE_Severe Curve'] = [[median_df['ROAD_CURVATURE_Severe Curve']] if x == 1 else x for x in crash_data['ROAD_CURVATURE_Unknown']]
median_crash_data['ROAD_CURVATURE_Moderate Curve'] = [[median_df['ROAD_CURVATURE_Moderate Curve']] if x == 1 else x for x in crash_data['ROAD_CURVATURE_Unknown']]
median_crash_data['ROAD_CURVATURE_Easy Curve'] = [[median_df['ROAD_CURVATURE_Easy Curve']] if x == 1 else x for x in crash_data['ROAD_CURVATURE_Unknown']]

median_crash_data['FLAT_HILL_Hill'] = [[median_df['FLAT_HILL_Hill']] if x == 1 else x for x in crash_data['FLAT_HILL_Unknown']]
median_crash_data['FLAT_HILL_Flat'] = [[median_df['FLAT_HILL_Flat']] if x == 1 else x for x in crash_data['FLAT_HILL_Unknown']]

median_crash_data['DIRN_ROLE1_DESC_West'] = [[median_df['DIRN_ROLE1_DESC_West']] if x == 1 else x for x in crash_data['DIRN_ROLE1_DESC_Unknown']]
median_crash_data['DIRN_ROLE1_DESC_South'] = [[median_df['DIRN_ROLE1_DESC_South']] if x == 1 else x for x in crash_data['DIRN_ROLE1_DESC_Unknown']]
median_crash_data['DIRN_ROLE1_DESC_0'] = [[median_df['DIRN_ROLE1_DESC_0']] if x == 1 else x for x in crash_data['DIRN_ROLE1_DESC_Unknown']]
median_crash_data['DIRN_ROLE1_DESC_East'] = [[median_df['DIRN_ROLE1_DESC_East']] if x == 1 else x for x in crash_data['DIRN_ROLE1_DESC_Unknown']]
median_crash_data['DIRN_ROLE1_DESC_North'] = [[median_df['DIRN_ROLE1_DESC_North']] if x == 1 else x for x in crash_data['DIRN_ROLE1_DESC_Unknown']]

median_crash_data['JUNCTION_TYPE_Y Type Junction'] = [[median_df['JUNCTION_TYPE_Y Type Junction']] if x == 1 else x for x in crash_data['JUNCTION_TYPE_Unknown']]
median_crash_data['JUNCTION_TYPE_X Type Junction'] = [[median_df['JUNCTION_TYPE_X Type Junction']] if x == 1 else x for x in crash_data['JUNCTION_TYPE_Unknown']]
median_crash_data['JUNCTION_TYPE_T Type Junction'] = [[median_df['JUNCTION_TYPE_T Type Junction']] if x == 1 else x for x in crash_data['JUNCTION_TYPE_Unknown']]
median_crash_data['JUNCTION_TYPE_Roundabout'] = [[median_df['JUNCTION_TYPE_Roundabout']] if x == 1 else x for x in crash_data['JUNCTION_TYPE_Unknown']]
median_crash_data['JUNCTION_TYPE_Multi Rd Join'] = [[median_df['JUNCTION_TYPE_Multi Rd Join']] if x == 1 else x for x in crash_data['JUNCTION_TYPE_Unknown']]
median_crash_data['JUNCTION_TYPE_Driveway'] = [[median_df['JUNCTION_TYPE_Driveway']] if x == 1 else x for x in crash_data['JUNCTION_TYPE_Unknown']]

median_crash_data = processData(median_crash_data, keep_col_array)
median_crash_data.to_csv('crash_data_median_unknowns.csv', index=False)

# %%
#convert values for mode
#having some issues with this section of code
mode_crash_data = crash_data

mode_crash_data['STREET_LIGHT_None'] = [[mode_df['STREET_LIGHT_None']] if x == 1 else x for x in crash_data['STREET_LIGHT_Unknown']]
#mode_df['WEATHER_A_Fine']
mode_crash_data['STREET_LIGHT_Off'] = [[mode_df['STREET_LIGHT_Off']] if x == 1 else x for x in crash_data['STREET_LIGHT_Unknown']]
mode_crash_data['STREET_LIGHT_On'] = [[mode_df['STREET_LIGHT_On']] if x == 1 else x for x in crash_data['STREET_LIGHT_Unknown']]
#print(mode_crash_data.loc[[22060]])

mode_crash_data['WEATHER_A_Fine'] = [[mode_df['WEATHER_A_Fine']] if x == 1 else x for x in crash_data['WEATHER_A_Unknown']]
mode_crash_data['WEATHER_A_Heavy Rain'] = [[mode_df['WEATHER_A_Heavy Rain']] if x == 1 else x for x in crash_data['WEATHER_A_Unknown']]
mode_crash_data['WEATHER_A_Light Rain'] = [[mode_df['WEATHER_A_Light Rain']] if x == 1 else x for x in crash_data['WEATHER_A_Unknown']]
mode_crash_data['WEATHER_A_Mist'] = [[mode_df['WEATHER_A_Mist']] if x == 1 else x for x in crash_data['WEATHER_A_Unknown']]
mode_crash_data['WEATHER_A_Snow'] = [[mode_df['WEATHER_A_Snow']] if x == 1 else x for x in crash_data['WEATHER_A_Unknown']]

mode_crash_data['LIGHT_Twilight'] = [[mode_df['LIGHT_Twilight']] if x == 1 else x for x in crash_data['LIGHT_Unknown']]
mode_crash_data['LIGHT_Overcast'] = [[mode_df['LIGHT_Overcast']] if x == 1 else x for x in crash_data['LIGHT_Unknown']]
mode_crash_data['LIGHT_Dark'] = [[mode_df['LIGHT_Dark']] if x == 1 else x for x in crash_data['LIGHT_Unknown']]
mode_crash_data['LIGHT_Bright Sun'] = [[mode_df['LIGHT_Bright Sun']] if x == 1 else x for x in crash_data['LIGHT_Unknown']]

mode_crash_data['ROAD_WET_Wet'] = [[mode_df['ROAD_WET_Wet']] if x == 1 else x for x in crash_data['ROAD_WET_Unknown']]
mode_crash_data['ROAD_WET_Ice/ Snow'] = [[mode_df['ROAD_WET_Ice/ Snow']] if x == 1 else x for x in crash_data['ROAD_WET_Unknown']]
median_crash_data['ROAD_WET_Dry'] = [[mode_df['ROAD_WET_Dry']] if x == 1 else x for x in crash_data['ROAD_WET_Unknown']]

mode_crash_data['ROAD_SURFACE_Unsealed'] = [[mode_df['ROAD_SURFACE_Unsealed']] if x == 1 else x for x in crash_data['ROAD_SURFACE_Unknown']]
mode_crash_data['ROAD_SURFACE_Sealed'] = [[mode_df['ROAD_SURFACE_Sealed']] if x == 1 else x for x in crash_data['ROAD_SURFACE_Unknown']]


mode_crash_data['ROAD_MARKINGS_Raised Island'] = [[mode_df['ROAD_MARKINGS_Raised Island']] if x == 1 else x for x in crash_data['ROAD_MARKINGS_Unknown']]
mode_crash_data['ROAD_MARKINGS_Ped Crossing'] = [[mode_df['ROAD_MARKINGS_Ped Crossing']] if x == 1 else x for x in crash_data['ROAD_MARKINGS_Unknown']]
mode_crash_data['ROAD_MARKINGS_Painted Island'] = [[mode_df['ROAD_MARKINGS_Painted Island']] if x == 1 else x for x in crash_data['ROAD_MARKINGS_Unknown']]
mode_crash_data['ROAD_MARKINGS_No Passing Lines'] = [[mode_df['ROAD_MARKINGS_No Passing Lines']] if x == 1 else x for x in crash_data['ROAD_MARKINGS_Unknown']]
mode_crash_data['ROAD_MARKINGS_No Marks'] = [[mode_df['ROAD_MARKINGS_No Marks']] if x == 1 else x for x in crash_data['ROAD_MARKINGS_Unknown']]
mode_crash_data['ROAD_MARKINGS_Centre Line'] = [[mode_df['ROAD_MARKINGS_Centre Line']] if x == 1 else x for x in crash_data['ROAD_MARKINGS_Unknown']]

mode_crash_data['ROAD_CURVATURE_Straight Road'] = [[mode_df['ROAD_CURVATURE_Straight Road']] if x == 1 else x for x in crash_data['ROAD_CURVATURE_Unknown']]
mode_crash_data['ROAD_CURVATURE_Severe Curve'] = [[mode_df['ROAD_CURVATURE_Severe Curve']] if x == 1 else x for x in crash_data['ROAD_CURVATURE_Unknown']]
mode_crash_data['ROAD_CURVATURE_Moderate Curve'] = [[mode_df['ROAD_CURVATURE_Moderate Curve']] if x == 1 else x for x in crash_data['ROAD_CURVATURE_Unknown']]
mode_crash_data['ROAD_CURVATURE_Easy Curve'] = [[mode_df['ROAD_CURVATURE_Easy Curve']] if x == 1 else x for x in crash_data['ROAD_CURVATURE_Unknown']]

mode_crash_data['FLAT_HILL_Hill'] = [[mode_df['FLAT_HILL_Hill']] if x == 1 else x for x in crash_data['FLAT_HILL_Unknown']]
mode_crash_data['FLAT_HILL_Flat'] = [[mode_df['FLAT_HILL_Flat']] if x == 1 else x for x in crash_data['FLAT_HILL_Unknown']]

mode_crash_data['DIRN_ROLE1_DESC_West'] = [[mode_df['DIRN_ROLE1_DESC_West']] if x == 1 else x for x in crash_data['DIRN_ROLE1_DESC_Unknown']]
mode_crash_data['DIRN_ROLE1_DESC_South'] = [[mode_df['DIRN_ROLE1_DESC_South']] if x == 1 else x for x in crash_data['DIRN_ROLE1_DESC_Unknown']]
mode_crash_data['DIRN_ROLE1_DESC_0'] = [[mode_df['DIRN_ROLE1_DESC_0']] if x == 1 else x for x in crash_data['DIRN_ROLE1_DESC_Unknown']]
mode_crash_data['DIRN_ROLE1_DESC_East'] = [[mode_df['DIRN_ROLE1_DESC_East']] if x == 1 else x for x in crash_data['DIRN_ROLE1_DESC_Unknown']]
mode_crash_data['DIRN_ROLE1_DESC_North'] = [[mode_df['DIRN_ROLE1_DESC_North']] if x == 1 else x for x in crash_data['DIRN_ROLE1_DESC_Unknown']]

mode_crash_data['JUNCTION_TYPE_Y Type Junction'] = [[mode_df['JUNCTION_TYPE_Y Type Junction']] if x == 1 else x for x in crash_data['JUNCTION_TYPE_Unknown']]
mode_crash_data['JUNCTION_TYPE_X Type Junction'] = [[mode_df['JUNCTION_TYPE_X Type Junction']] if x == 1 else x for x in crash_data['JUNCTION_TYPE_Unknown']]
mode_crash_data['JUNCTION_TYPE_T Type Junction'] = [[mode_df['JUNCTION_TYPE_T Type Junction']] if x == 1 else x for x in crash_data['JUNCTION_TYPE_Unknown']]
mode_crash_data['JUNCTION_TYPE_Roundabout'] = [[mode_df['JUNCTION_TYPE_Roundabout']] if x == 1 else x for x in crash_data['JUNCTION_TYPE_Unknown']]
mode_crash_data['JUNCTION_TYPE_Multi Rd Join'] = [[mode_df['JUNCTION_TYPE_Multi Rd Join']] if x == 1 else x for x in crash_data['JUNCTION_TYPE_Unknown']]
mode_crash_data['JUNCTION_TYPE_Driveway'] = [[mode_df['JUNCTION_TYPE_Driveway']] if x == 1 else x for x in crash_data['JUNCTION_TYPE_Unknown']]

mode_crash_data = processData(mode_crash_data, keep_col_array)
mode_crash_data.to_csv('crash_data_mode_unknowns.csv', index=False)
# Out:
# c:\users\jaedyn\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-38c7625f3b61> in <module>
#      56
#      57 mode_crash_data = processData(mode_crash_data, keep_col_array)
# ---> 58 mode_crash_data.to_csv('crash_data_mode_unknowns.csv', index=False)
#
# ...
